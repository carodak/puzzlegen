# %% [markdown]
# # Puzzle Generation Code for the Executive Functioning Task (https://osf.io/3pz74/wiki/home/)
# Developed by Caroline DAKOURE

# %% [markdown]
# ## Import the package

# %%
# !pip install puzzlegen
# Out:
# Collecting puzzlegen
#   Downloading puzzlegen-0.1.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting matplotlib==3.10.3 (from puzzlegen)
#   Downloading matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from puzzlegen) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.10.3->puzzlegen) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.3->puzzlegen) (1.17.0)
# Downloading puzzlegen-0.1.2-py3-none-any.whl (33 kB)
# Downloading matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 74.6 MB/s eta 0:00:00
# Installing collected packages: matplotlib, puzzlegen
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# Successfully installed matplotlib-3.10.3 puzzlegen-0.1.2

# %% [markdown]
# ## Randomly generate 1 puzzle and test its solvability within a specified number of moves (e.g, 5 moves maximum).

# %%
from puzzlegen.frontend import SinglePuzzle

# 1. Create a puzzle game
puzzle = SinglePuzzle(nb_blocks=10, colors=['red', 'blue', 'gray'], nb_moves=5, grid_size=(12, 12))

# 2. Generate a random puzzle
puzzle.generate()

# 3. Display the puzzle
puzzle.show()

# 4. Attempt to solve the puzzle (i.e., find a solution within nb_moves)
solution = puzzle.solve()

# 5. Save the solution and batch as files
puzzle.show_solution()
# Out:
# ╔════════════════════════════════════════════════╗
# ║ 🎲🎉 Here is your randomly generated puzzle! 🎉🎲  ║
# ║ ────────────────────────────────────────────── ║
# ╚════════════════════════════════════════════════╝
# 🖼️  Close the figure window to continue...
# ╔════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# ║ 🔹 Shorter representation of the puzzle:                                                                                                                                                                                                ║
# ║ {(6, 6): <Color: red>, (7, 6): <Color: red>, (8, 6): <Color: gray>, (8, 7): <Color: gray>, (9, 6): <Color: blue>, (9, 7): <Color: blue>, (10, 6): <Color: gray>, (10, 7): <Color: blue>, (11, 6): <Color: red>, (11, 7): <Color: red>} ║
# ╚════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# Solving Puzzle Progress: 100%|██████████| 5/5 [00:00<00:00, 15.26it/s, Processed=208, Queue Size=2919]
# Found a solution: [{(6, 6): <Color: red>, (7, 6): <Color: red>, (8, 6): <Color: gray>, (8, 7): <Color: gray>, (9, 6): <Color: blue>, (9, 7): <Color: blue>, (10, 6): <Color: gray>, (10, 7): <Color: blue>, (11, 6): <Color: red>, (11, 7): <Color: red>}, {(7, 6): <Color: red>, (7, 7): <Color: red>, (8, 6): <Color: gray>, (8, 7): <Color: gray>, (9, 6): <Color: blue>, (9, 7): <Color: blue>, (10, 6): <Color: gray>, (10, 7): <Color: blue>, (11, 6): <Color: red>, (11, 7): <Color: red>}, {(7, 6): <Color: red>, (8, 6): <Color: gray>, (8, 7): <Color: red>, (9, 6): <Color: blue>, (9, 7): <Color: gray>, (10, 6): <Color: gray>, (10, 7): <Color: blue>, (11, 6): <Color: red>, (11, 7): <Color: blue>, (11, 8): <Color: red>}, {(8, 6): <Color: gray>, (8, 7): <Color: red>, (9, 6): <Color: blue>, (9, 7): <Color: gray>, (10, 6): <Color: gray>, (10, 7): <Color: blue>, (11, 5): <Color: red>, (11, 6): <Color: red>, (11, 7): <Color: blue>, (11, 8): <Color: red>}, {}] in 4 moves
#
# 🖼️  Close the figure window to continue...

# %% [markdown]
# ## Generate a batch of puzzles solvable in 5 moves maximum

# %% [markdown]
# Now, let's generate a lot of puzzles. In this process, puzzles that cannot be solved within the specified maximum number of moves (nb_moves) are automatically discarded. Only puzzles solvable in nb_moves moves or fewer are kept.

# %%
from puzzlegen.frontend import PuzzleBatch

# 1. Create a batch of puzzles
batch = PuzzleBatch(
    blocks_range=(6, 10),
    colors_range=(2, 4),
    colors_blocks=['blue', 'red', 'gray'],
    nb_moves=5,
    grid_size=(12, 6),
    stack_probability=0.75
)

# 2. Generate the batch
batch.generate()

# 3. Show statistics and save the results
batch.show_stats()
batch.save_pdf("batch_puzzles.pdf")
batch.save_csv("batch_puzzles.csv")
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║ Generating a batch of puzzles with the following parameters: ║
# ║ - Block count range: (6, 10)                                 ║
# ║ - Color count range: (2, 4)                                  ║
# ║ - Color palette: ['blue', 'red', 'gray']                     ║
# ║ - Max number of moves: 5                                     ║
# ║ - Grid size: (12, 6)                                         ║
# ║ - Stack probability: 0.75                                    ║
# ╚══════════════════════════════════════════════════════════════╝
# 🧩 Puzzle Batch Generation – Overall Progress:   0%|          | 0/9 [00:00<?, ?it/s]INFO:puzzlegen.core.batch_generator:Generating puzzle for 6 blocks, colors: ['blue', 'red'], grid size: (12, 6)
# INFO:puzzlegen.core.batch_generator:Generating puzzle for 7 blocks, colors: ['blue', 'red'], grid size: (12, 6)
# 🧩 Puzzle Batch Generation – Overall Progress:  22%|██▏       | 2/9 [00:00<00:00, 11.45it/s]INFO:puzzlegen.core.batch_generator:Generating puzzle for 8 blocks, colors: ['blue', 'red'], grid size: (12, 6)
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# Found a solution: [{(9, 5): <Color: red>, (10, 3): <Color: red>, (10, 5): <Color: blue>, (11, 2): <Color: red>, (11, 3): <Color: blue>, (11, 5): <Color: blue>}, {(11, 2): <Color: red>, (11, 3): <Color: red>, (11, 5): <Color: red>}, {}] in 2 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# Found a solution: [{(5, 3): <Color: red>, (6, 3): <Color: blue>, (7, 3): <Color: blue>, (8, 3): <Color: red>, (9, 3): <Color: red>, (10, 3): <Color: blue>, (11, 3): <Color: red>}, {(6, 3): <Color: blue>, (7, 3): <Color: blue>, (8, 3): <Color: red>, (9, 3): <Color: red>, (10, 3): <Color: blue>, (11, 2): <Color: red>, (11, 3): <Color: red>}, {(6, 3): <Color: blue>, (7, 3): <Color: blue>, (8, 3): <Color: red>, (9, 3): <Color: red>, (10, 3): <Color: blue>, (11, 1): <Color: red>, (11, 3): <Color: red>}, {(7, 3): <Color: blue>, (8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 3): <Color: blue>, (11, 1): <Color: red>, (11, 3): <Color: red>, (11, 4): <Color: red>}, {}] in 4 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# INFO:puzzlegen.core.batch_generator:Generating puzzle for 9 blocks, colors: ['blue', 'red'], grid size: (12, 6)
# 🧩 Puzzle Batch Generation – Overall Progress:  44%|████▍     | 4/9 [00:01<00:01,  2.58it/s]INFO:puzzlegen.core.batch_generator:Generating puzzle for 10 blocks, colors: ['blue', 'red'], grid size: (12, 6)
# Found a solution: [{(8, 3): <Color: blue>, (9, 1): <Color: blue>, (9, 3): <Color: red>, (10, 1): <Color: blue>, (10, 3): <Color: red>, (11, 1): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: blue>}, {(8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 1): <Color: blue>, (10, 3): <Color: red>, (11, 0): <Color: blue>, (11, 1): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: blue>}, {(8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 0): <Color: blue>, (11, 1): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: blue>}, {(8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 0): <Color: blue>, (11, 1): <Color: blue>, (11, 2): <Color: red>, (11, 3): <Color: blue>}, {(9, 2): <Color: blue>, (9, 3): <Color: red>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 0): <Color: blue>, (11, 1): <Color: blue>, (11, 2): <Color: red>, (11, 3): <Color: blue>}, {}] in 5 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# Found a solution: [{(7, 2): <Color: red>, (8, 2): <Color: red>, (8, 3): <Color: blue>, (9, 2): <Color: blue>, (9, 3): <Color: blue>, (10, 2): <Color: red>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: red>}, {(9, 2): <Color: red>, (9, 3): <Color: blue>, (10, 2): <Color: red>, (10, 3): <Color: blue>, (11, 2): <Color: blue>, (11, 3): <Color: red>}, {}] in 2 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# 🧩 Puzzle Batch Generation – Overall Progress:  56%|█████▌    | 5/9 [00:01<00:01,  2.20it/s]INFO:puzzlegen.core.batch_generator:Generating puzzle for 9 blocks, colors: ['blue', 'red', 'gray'], grid size: (12, 6)
# Found a solution: [{(9, 1): <Color: red>, (9, 3): <Color: blue>, (10, 1): <Color: blue>, (10, 3): <Color: blue>, (10, 4): <Color: red>, (10, 5): <Color: blue>, (11, 1): <Color: blue>, (11, 3): <Color: red>, (11, 4): <Color: blue>, (11, 5): <Color: red>}, {(9, 3): <Color: blue>, (10, 1): <Color: red>, (10, 3): <Color: blue>, (10, 4): <Color: red>, (10, 5): <Color: blue>, (11, 1): <Color: blue>, (11, 2): <Color: blue>, (11, 3): <Color: red>, (11, 4): <Color: blue>, (11, 5): <Color: red>}, {(9, 3): <Color: blue>, (10, 2): <Color: red>, (10, 3): <Color: blue>, (10, 4): <Color: red>, (10, 5): <Color: blue>, (11, 1): <Color: blue>, (11, 2): <Color: blue>, (11, 3): <Color: red>, (11, 4): <Color: blue>, (11, 5): <Color: red>}, {(9, 3): <Color: blue>, (10, 2): <Color: red>, (10, 3): <Color: red>, (10, 4): <Color: blue>, (10, 5): <Color: blue>, (11, 1): <Color: blue>, (11, 2): <Color: blue>, (11, 3): <Color: red>, (11, 4): <Color: blue>, (11, 5): <Color: red>}, {}] in 4 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# INFO:puzzlegen.core.bfs_solver:Did not find a solution in 5 moves.
# 🧩 Puzzle Batch Generation – Overall Progress:  67%|██████▋   | 6/9 [00:11<00:09,  3.02s/it]INFO:puzzlegen.core.batch_generator:Generating puzzle for 10 blocks, colors: ['blue', 'red', 'gray'], grid size: (12, 6)
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# Found a solution: [{(6, 3): <Color: blue>, (7, 3): <Color: red>, (8, 3): <Color: blue>, (9, 3): <Color: gray>, (9, 5): <Color: gray>, (10, 3): <Color: gray>, (10, 5): <Color: red>, (11, 3): <Color: blue>, (11, 5): <Color: red>}, {(7, 3): <Color: red>, (8, 3): <Color: blue>, (9, 3): <Color: gray>, (9, 5): <Color: gray>, (10, 3): <Color: gray>, (10, 5): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: blue>, (11, 5): <Color: red>}, {(7, 3): <Color: red>, (8, 3): <Color: blue>, (9, 3): <Color: gray>, (10, 3): <Color: gray>, (10, 5): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: blue>, (11, 4): <Color: gray>, (11, 5): <Color: red>}, {(7, 3): <Color: red>, (8, 3): <Color: blue>, (9, 3): <Color: gray>, (10, 3): <Color: gray>, (10, 4): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: blue>, (11, 4): <Color: gray>, (11, 5): <Color: red>}, {}] in 4 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# INFO:puzzlegen.core.bfs_solver:Did not find a solution in 5 moves.
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# 🧩 Puzzle Batch Generation – Overall Progress:  78%|███████▊  | 7/9 [00:39<00:21, 10.71s/it]INFO:puzzlegen.core.batch_generator:Generating puzzle for 9 blocks, colors: ['blue', 'red', 'gray'], grid size: (12, 6)
# Found a solution: [{(2, 3): <Color: red>, (3, 3): <Color: blue>, (4, 3): <Color: gray>, (5, 3): <Color: blue>, (6, 3): <Color: red>, (7, 3): <Color: gray>, (8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 3): <Color: red>, (11, 3): <Color: gray>}, {(3, 3): <Color: red>, (4, 3): <Color: gray>, (5, 3): <Color: blue>, (6, 3): <Color: red>, (7, 3): <Color: gray>, (8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 3): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: gray>}, {(4, 3): <Color: red>, (5, 3): <Color: blue>, (6, 3): <Color: red>, (7, 3): <Color: gray>, (8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 3): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: gray>, (11, 4): <Color: gray>}, {(5, 3): <Color: red>, (6, 3): <Color: red>, (7, 3): <Color: gray>, (8, 3): <Color: blue>, (9, 3): <Color: red>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 2): <Color: blue>, (11, 3): <Color: gray>, (11, 4): <Color: gray>}, {(6, 3): <Color: red>, (7, 3): <Color: red>, (8, 3): <Color: gray>, (9, 3): <Color: red>, (10, 3): <Color: red>, (11, 3): <Color: gray>, (11, 4): <Color: gray>}, {}] in 5 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# INFO:puzzlegen.core.bfs_solver:Did not find a solution in 5 moves.
# 🧩 Puzzle Batch Generation – Overall Progress:  89%|████████▉ | 8/9 [01:06<00:15, 15.53s/it]INFO:puzzlegen.core.batch_generator:Generating puzzle for 10 blocks, colors: ['blue', 'red', 'gray'], grid size: (12, 6)
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# Found a solution: [{(6, 3): <Color: gray>, (7, 3): <Color: red>, (8, 3): <Color: gray>, (9, 3): <Color: blue>, (10, 2): <Color: gray>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: blue>, (11, 4): <Color: blue>}, {(7, 3): <Color: gray>, (8, 3): <Color: gray>, (9, 2): <Color: red>, (9, 3): <Color: blue>, (10, 2): <Color: gray>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: blue>, (11, 4): <Color: blue>}, {(7, 3): <Color: gray>, (8, 3): <Color: gray>, (9, 3): <Color: blue>, (10, 3): <Color: gray>, (11, 3): <Color: blue>, (11, 4): <Color: blue>}, {}] in 3 moves
#
# ╔════════════════════════════════════════════╗
# ║ Attempting to solve puzzle in ≤ 5 moves... ║
# ║ Using Breadth-First Search (BFS) strategy. ║
# ╚════════════════════════════════════════════╝
# 🧩 Puzzle Batch Generation – Overall Progress: 100%|██████████| 9/9 [01:15<00:00,  8.35s/it]
# Found a solution: [{(2, 3): <Color: red>, (3, 3): <Color: gray>, (4, 3): <Color: red>, (5, 3): <Color: blue>, (6, 3): <Color: gray>, (7, 3): <Color: red>, (8, 3): <Color: gray>, (9, 3): <Color: blue>, (10, 3): <Color: red>, (11, 3): <Color: blue>}, {(3, 3): <Color: gray>, (4, 3): <Color: red>, (5, 3): <Color: blue>, (6, 3): <Color: gray>, (7, 3): <Color: red>, (8, 3): <Color: gray>, (9, 3): <Color: blue>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: blue>}, {(4, 3): <Color: gray>, (5, 3): <Color: red>, (6, 3): <Color: gray>, (7, 3): <Color: red>, (8, 3): <Color: gray>, (9, 3): <Color: blue>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: blue>}, {(5, 3): <Color: gray>, (6, 3): <Color: gray>, (7, 3): <Color: red>, (8, 3): <Color: gray>, (9, 2): <Color: red>, (9, 3): <Color: blue>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: blue>}, {(8, 2): <Color: red>, (9, 2): <Color: red>, (9, 3): <Color: blue>, (10, 2): <Color: blue>, (10, 3): <Color: red>, (11, 2): <Color: red>, (11, 3): <Color: blue>}, {}] in 5 moves
#
# Batch generation completed.
# stats:  {'solvable_in_1_moves': 0, 'solvable_in_2_moves': 2, 'solvable_in_3_moves': 1, 'solvable_in_4_moves': 3, 'solvable_in_5_moves': 3}
# 🖼️  Close the figure window to continue...
# File downloaded in browser (Colab): batch_puzzles.pdf
# 🖼️  Close the figure window to continue...
# PDF saved as batch_puzzles.pdf
# File downloaded in browser (Colab): batch_puzzles.csv
# CSV saved as batch_puzzles.csv
